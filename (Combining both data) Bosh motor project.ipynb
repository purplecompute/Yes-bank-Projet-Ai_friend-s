# %%
import pandas as pd
import os
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
os.getcwd()

# %%
files=os.listdir('/content/drive/MyDrive/Working Motor')

# %%
files

# %%
files.pop()

# %%
files

# %%
df=pd.read_csv('/content/drive/MyDrive/Working Motor/'+files[0])
df1=pd.read_csv('/content/drive/MyDrive/Working Motor/'+files[1])
df2=pd.read_csv('/content/drive/MyDrive/Working Motor/'+files[2])

# %%
df

# %%
df.isnull().sum()

# %%
df1.isnull().sum()

# %%
df2.isnull().sum()

# %%
df['Condition'] ='With Water'
df1['Condition'] ='With Pressure'
df2['Condition'] ='dry run'

# %%
df3=pd.concat([df,df1,df2],axis=0)

# %%
df.isnull().sum()

# %%
df3.shape

# %%
df3.to_csv('/content/drive/MyDrive/Working Motor/working motor data.csv')

# %%
df_faulty=pd.read_csv('/content/drive/MyDrive/Working Motor/faulty motor data.csv')

# %%
$$$$$$$$$$$$$
# Out:
#   File "<ipython-input-18-a8b27b44f542>", line 1
#     $$$$$$$$$$$$$
#     ^
# SyntaxError: invalid syntax

# %%
df_combine=pd.concat([df3,df_faulty],axis=0)

# %%
df_combine.columns

# %%
df_combine['Unnamed: 0'].unique()

# %%
df_combine['Unnamed: 0'].value_counts()

# %%
df_combine=df_combine.drop('Unnamed: 0',axis=1)

# %%
df_combine

# %%
df_combine.isnull().sum()

# %%
df_combine.to_csv('/content/drive/MyDrive/Working Motor/bosh_motor_combine_data1.csv')
